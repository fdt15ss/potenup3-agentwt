# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

model = OpenAI()

result = model.responses.create(
    model="gpt-5-nano",
    input="안녕 반가워 내 이름은 임경빈이야",
)

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-5.4-mini")

model.invoke("대한민국의 수도는?")
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 12, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DV6Wjp4OvHlYq7uX3yzBVep4HWJna', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9410-e683-7692-bc1d-74076ccd7d52-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 13, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model = init_chat_model(
    "gpt-5.4-nano",
    temperature=0.8,
    timeout=30,
    max_tokens=100,
    max_retries=2,
)

model.invoke("대한민국의 수도는?")
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 12, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DV6dOte9W3wt1S39hxAoQGEAHdl8V', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9417-33d6-7eb1-a8ea-d918a2ebc6c6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 13, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model = init_chat_model("gpt-5.4-mini")
# [실습 2] stream: 답변을 실시간으로 조각조각 받기
print("--- stream 시작 ---")
for chunk in model.stream("대한민국의 사계절에 대해 설명해줘"):
    # chunk.content에 글자 조각이 들어있음
    # end=""는 줄바꿈을 하지 않고 옆으로 붙여서 출력하라는 뜻
    print(chunk.content, end="", flush=True)
print("\n--- stream 끝 ---")
# Out:
# --- stream 시작 ---
# 대한민국은 **뚜렷한 사계절**이 있는 나라로, 계절마다 날씨와 풍경, 생활 방식이 크게 달라집니다.
#
# ### 1. 봄 (3월~5월)
# - 날씨가 점점 따뜻해지고 꽃이 피기 시작합니다.
# - 대표적으로 **벚꽃, 개나리, 진달래**가 많이 피어 아름다운 풍경을 볼 수 있습니다.
# - 일교차가 커서 아침저녁은 쌀쌀할 수 있습니다.
# - 황사나 미세먼지가 나타나기도 합니다.
#
# ### 2. 여름 (6월~8월)
# - 덥고 습한 날씨가 이어집니다.
# - **장마**가 있어 비가 많이 오는 시기가 있습니다.
# - 이후에는 무더위와 함께 열대야가 나타나기도 합니다.
# - 해변, 계곡, 워터파크 같은 여름철 활동이 활발합니다.
#
# ### 3. 가을 (9월~11월)
# - 날씨가 선선하고 하늘이 맑아지며 가장 쾌적한 계절로 많이 꼽힙니다.
# - 나뭇잎이 빨갛게, 노랗게 물드는 **단풍**이 아름답습니다.
# - 추석 같은 큰 명절이 있는 시기이기도 합니다.
# - 아침저녁으로는 꽤 서늘해집니다.
#
# ### 4. 겨울 (12월~2월)
# - 날씨가 매우 춥고 건조합니다.
# - 지역에 따라 눈이 많이 오기도 하며, 한파가 찾아오기도 합니다.
# - 난방이 중요한 계절이며, 두꺼운 외투와 장갑, 목도리가 필요합니다.
# - 스키장, 눈썰매장 등 겨울 스포츠를 즐기기 좋습니다.
#
# ### 정리
# 대한민국의 사계절은
# - **봄: 꽃이 피는 계절**
# - **여름: 덥고 비가 많은 계절**
# - **가을: 맑고 단풍이 아름다운 계절**
# - **겨울: 춥고 눈이 오는 계절**
# 이라고 볼 수 있습니다.
#
# 원하시면 제가 **초등학생도 이해하기 쉽게** 다시 설명해드릴 수도 있어요.
# --- stream 끝 ---

# %%
# [실습 3] batch: 질문 리스트 -> 답변 리스트
questions = ["사과를 영어로 뭐야?", "바나나를 영어로 뭐야?", "포도를 영어로 뭐야?"]

print("--- batch 시작 (잠시 대기...) ---")
results = model.batch(questions)

# 결과 리스트 하나씩 출력
for res in results:
    print(f"답변: {res.content}")
print("--- batch 끝 ---")
# Out:
# --- batch 시작 (잠시 대기...) ---
# 답변: 사과는 영어로 **apple**이에요.
# 답변: 바나나는 영어로 **banana**예요.
# 답변: “포도”는 영어로 **grape**예요.
# --- batch 끝 ---

# %%
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")

response = model.invoke("대한민국의 수도는?")
response.content
# Out:
# '대한민국의 수도는 **서울**입니다.'
