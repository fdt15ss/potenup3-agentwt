# %%
from langchain_core.documents import Document

document = Document("이 데이터는 도규먼트입니다.")
document
# Out:
# Document(metadata={}, page_content='이 데이터는 도규먼트입니다.')

# %%
document.metadata["author"] = "김한호"

# %%
document.metadata
# Out:
# {'author': '김한호'}

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("수업 데이터/ai.txt", encoding="utf-8")
documents = loader.load()

documents
# Out:
# [Document(metadata={'source': '수업 데이터/ai.txt'}, page_content='\n인공지능 (AI):*인간의 지능을 모방해 학습, 추론, 문제 해결 등을 수행하는 기술 전반\n머신러닝 (ML):*데이터를 통해 스스로 규칙을 학습하는 인공지능의 한 분야\n딥러닝 (DL):*인공신경망을 이용해 복잡한 패턴을 학습하는 머신러닝의 하위 분야\n\n지도학습: 정답(라벨)이 있는 데이터로 학습\n비지도학습: 정답 없이 데이터의 구조나 패턴을 발견\n강화학습: 행동에 대한 보상을 통해 최적의 전략을 학습\n\n인공신경망 (ANN):*인간의 뇌 구조를 모방한 모델\n합성곱 신경망 (CNN):*이미지 처리에 강한 신경망 구조\n순환 신경망 (RNN):*순차 데이터(문장, 시계열 등)를 처리하는 구조\n트랜스포머: 자연어 처리에서 널리 쓰이는 최신 구조\n\n데이터셋: 모델 학습에 사용되는 데이터 모음\n특징: 데이터를 설명하는 속성\n레이블: 지도학습에서의 정답 값\n과적합: 학습 데이터에만 지나치게 맞춰져 일반화가 안 되는 상태\n일반화: 새로운 데이터에도 잘 작동하는 능력\n\n자연어 처리 (NLP):*인간 언어를 이해하고 생성하는 기술\n컴퓨터 비전: 이미지·영상 데이터를 이해하는 기술\n생성형 인공지능: 텍스트, 이미지 등 새로운 콘텐츠를 생성하는 AI\n대형 언어 모델 (LLM):*방대한 텍스트로 학습된 언어 생성 모델')]

# %%
len(documents)
# Out:
# 1

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

loader = PyMuPDFLoader("수업 데이터/wt_data.pdf")

documents = loader.load()
documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-14T08:34:37+00:00', 'source': '수업 데이터/wt_data.pdf', 'file_path': '수업 데이터/wt_data.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-14T08:34:37+00:00', 'trapped': '', 'modDate': "D:20260414083437+00'00'", 'creationDate': "D:20260414083437+00'00'", 'page': 0}, page_content="Page 1\nRAG Practice PDF Sample\nRAG 실습용 PDF 예시\n학생지원센터 안내서 / Sample document for retrieval-augmented generation practice\n문서 목적\n이 문서는 RAG 실습을 위해 의도적으로 구성한 예시 자료입니다. FAQ, 정책, 절차, 연락처, 예외 규정, 비교 표를\n함께 포함해 문서 로딩, 청킹, 임베딩, 검색, 답변 생성 실습에 활용할 수 있습니다.\n실습 포인트\n1) 제목과 소제목이 분명한 구조형 문서 2) 비슷하지만 다른 규정 문장 3) 표와 리스트가 섞인 반정형 데이터 4)\n예외 조항이 포함된 정책형 문장\n권장 활용 예시\n•\n학생이 '상담 예약은 언제까지 취소할 수 있나요?'라고 물으면 정책 조항을 검색해 답하기\n•\n장학금, 상담, 비교과 프로그램 등 여러 섹션 중 관련 영역만 정확히 검색하기\n•\n표에 있는 운영시간과 본문에 있는 예외규정을 함께 결합해 답변
# ...

# %%
len(documents)
# Out:
# 6

# %%
# uv add unstructured openpyxl
from langchain_community.document_loaders import UnstructuredExcelLoader

# %%
# csv
from langchain_community.document_loaders import csv_loader

# %%
# word. docx
from langchain_community.document_loaders import (
    Docx2txtLoader,
    UnstructuredWordDocumentLoader,
)

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
import os

os.environ["HF_HUB_DISABLE_SYMLINKS"] = "1"

from langchain_docling import DoclingLoader

loader = DoclingLoader(file_path=["수업 데이터/wt_data.pdf"])
documents = loader.load()

documents
# Out:
# [INFO] 2026-04-27 15:53:20,520 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:53:20,521 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:53:20,533 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:53:20,534 [RapidOCR] main.py:50: Using C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:53:20,640 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:53:20,641 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:53:20,642 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
from langchain_docling import DoclingLoader
from langchain_docling.loader import ExportType

loader = DoclingLoader(
    file_path=["수업 데이터/wt_data.pdf", "https://arxiv.org/pdf/2408.09869"],
    export_type=ExportType.MARKDOWN,
)

documents = loader.load()
# Out:
# [INFO] 2026-04-27 15:54:56,236 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:54:56,237 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:54:56,248 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:54:56,248 [RapidOCR] main.py:50: Using C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:54:56,358 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:54:56,359 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:54:56,361 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
documents
# Out:
# [Document(metadata={'source': '수업 데이터/wt_data.pdf'}, page_content="## RAG 실습용 PDF 예시\n\n학생지원센터 안내서 / Sample document for retrieval-augmented generation practice\n\n## 문서 목적\n\n이 문서는 RAG 실습을 위해 의도적으로 구성한 예시 자료입니다. FAQ, 정책, 절차, 연락처, 예외 규정, 비교 표를 함께 포함해 문서 로딩, 청킹, 임베딩, 검색, 답변 생성 실습에 활용할 수 있습니다.\n\n## 실습 포인트\n\n- 1) 제목과 소제목이 분명한 구조형 문서 2) 비슷하지만 다른 규정 문장 3) 표와 리스트가 섞인 반정형 데이터 4) 예외 조항이 포함된 정책형 문장\n\n## 권장 활용 예시\n\n- 학생이 '상담 예약은 언제까지 취소할 수 있나요?'라고 물으면 정책 조항을 검색해 답하기\n- 장학금, 상담, 비교과 프로그램 등 여러 섹션 중 관련 영역만 정확히 검색하기\n- 표에 있는 운영시간과 본문에 있는 예외규정을 함께 결합해 답변하기\n- 청크 크기와 overlap에 따라 검색 품질이 어떻게 달라지는지 비교하기\n\n버전 1.0 / 발행일 2026-04-14 / 발행처 예시대학교 학생지원센터\n\n## 1. 센터 개요\n\n예시대학교 학생지원센터는 학업, 진로, 심리상담, 비교과 프로그램, 기초 행정 문의를 한 곳에서 지원하는 통합 서비스 창구이다. 센터는 재학생을 기본 대상으로 운영하며, 휴학생은 일부 서비스만 이용할 수 있다. 졸업생은 진로상담과 취업특강 자료 열람은 가능하지만 장학금 상담은 지원 대상이 아니다.\n\n## 핵심 서비스\n\n학업상담, 심리상담, 장학금 안내, 비교과 프로그램 신청 지원, 증명서 발급 안내, 기초 진로설계, 학습 코칭 , 멘토링 매칭\n\n## 1-1. 운영시간\n\n| 구분             | 운영시간      | 비고                     |\n|-------
# ...

# %%
len(documents)
# Out:
# 2

# %%
# !uv add langchain-text-splitters
# Out:
# Resolved 322 packages in 149ms
# Checked 294 packages in 9ms

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = """
미국 스탠퍼드대 인간 중심 인공지능 연구소(HAI)가 최근 한국 AI 모델 5개를 '주목할 만한 AI'에 이름 올렸지만 사실상 8개로 집계된 것으로 확인됐다. HAI는 현재 해당 수치에 맞게 보고서를 수정 중이라고 밝혔다.

23일 지디넷코리아 취재에 따르면 스탠퍼드대 HAI는 에포크 AI(Epoch AI) 보고서 내 '주목할 만한 AI' 모델 데이터베이스(DB)에서 한국 모델 수를 기존 5개에서 8개로 정정한 것으로 전해졌다. HAI 관계자는 "DB 업데이트 과정에서 일부 모델이 추가 반영되거나 수정된 데 따른 것"이라고 이메일을 통해 밝혔다.

현재 등록된 모델은 이달 기준 업스테이지 '솔라 오픈 100B'를 비롯해 LG AI연구원 'K-엑사원', '엑사원 4.0(32B)', '엑사원 패스 2.0', '엑사원 딥(32B)', NC AI '배키', SK텔레콤 '에이닷엑스(A.X) K1', 네이버클라우드 '하이퍼클로바 X 시드 32B 싱크'다.
"""

splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=10)

chunks = splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"[Chunk {i}]")
    print(chunk)
    print("----------------------------")
# Out:
# [Chunk 0]
# 미국 스탠퍼드대 인간 중심 인공지능 연구소(HAI)가 최근 한국 AI 모델 5개를 '주목할 만한 AI'에 이름 올렸지만 사실상 8개로 집계된 것으로 확인됐다. HAI는 현재 해당
# ----------------------------
# [Chunk 1]
# 현재 해당 수치에 맞게 보고서를 수정 중이라고 밝혔다.
# ----------------------------
# [Chunk 2]
# 23일 지디넷코리아 취재에 따르면 스탠퍼드대 HAI는 에포크 AI(Epoch AI) 보고서 내 '주목할 만한 AI' 모델 데이터베이스(DB)에서 한국 모델 수를 기존 5개에서
# ----------------------------
# [Chunk 3]
# 기존 5개에서 8개로 정정한 것으로 전해졌다. HAI 관계자는 "DB 업데이트 과정에서 일부 모델이 추가 반영되거나 수정된 데 따른 것"이라고 이메일을 통해 밝혔다.
# ----------------------------
# [Chunk 4]
# 현재 등록된 모델은 이달 기준 업스테이지 '솔라 오픈 100B'를 비롯해 LG AI연구원 'K-엑사원', '엑사원 4.0(32B)', '엑사원 패스 2.0', '엑사원
# ----------------------------
# [Chunk 5]
# '엑사원 딥(32B)', NC AI '배키', SK텔레콤 '에이닷엑스(A.X) K1', 네이버클라우드 '하이퍼클로바 X 시드 32B 싱크'다.
# ----------------------------

# %%
from langchain_docling import DoclingLoader
from langchain_docling.loader import ExportType
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader = DoclingLoader(
    file_path=["수업 데이터/wt_data.pdf"], export_type=ExportType.MARKDOWN
)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=100)

split_documents = splitter.split_documents(documents)

split_documents
# Out:
# [INFO] 2026-04-27 15:57:01,934 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:57:01,935 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:57:01,947 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:57:01,947 [RapidOCR] main.py:50: Using C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 15:57:02,058 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 15:57:02,059 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 15:57:02,061 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter

code = """
def greet(name):
    return f"Hello, {name}"

def add(a, b):
    return a + b

class User:
    def __init__(self, name):
        self.name = name
"""

splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, chunk_size=80, chunk_overlap=10
)

chunks = splitter.split_text(code)

for i, chunk in enumerate(chunks):
    print(f"[Chunk {i}]")
    print(chunk)
    print("-" * 30)
# Out:
# [Chunk 0]
# def greet(name):
#     return f"Hello, {name}"
#
# def add(a, b):
#     return a + b
# ------------------------------
# [Chunk 1]
# class User:
#     def __init__(self, name):
#         self.name = name
# ------------------------------

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

vector = embeddings.embed_query("안녕")
vector
# Out:
# [-0.013854836113750935,
#  -0.010460599325597286,
#  0.008594762533903122,
#  -0.01656757853925228,
#  -0.012412451207637787,
#  0.020828569307923317,
#  -0.02204599417746067,
#  0.0030733386520296335,
#  -0.009322571568191051,
#  -0.000937054050154984,
#  0.012723423540592194,
#  0.002019669860601425,
#  -0.02309139259159565,
#  -0.012630793265998363,
#  0.005263382103294134,
#  0.002939355792477727,
#  0.03419378772377968,
#  0.00018526046187616885,
#  0.021344652399420738,
#  -0.021794570609927177,
#  -0.000507812132127583,
#  -0.018896566703915596,
#  -0.005137669388204813,
#  -0.00862122792750597,
#  0.006308780517429113,
#  0.015456016175448895,
#  0.011691258288919926,
#  -0.01734831929206848,
#  0.01095021702349186,
#  -0.02391183190047741,
#  0.016064729541540146,
#  0.008687392808496952,
#  -0.027577342465519905,
#  -0.015164892189204693,
#  0.0027193590067327023,
#  -0.016924867406487465,
#  -0.003156044287607074,
#  -0.010831120423972607,
#  0.0060011157765984535,
# ...

# %%
from langchain_docling import DoclingLoader
from langchain_docling.loader import ExportType
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

loader = DoclingLoader(
    file_path=["수업 데이터/wt_data.pdf"], export_type=ExportType.MARKDOWN
)
documents = loader.load()  # 1

splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=100)

split_documents = splitter.split_documents(documents)  # 20

texts = [doc.page_content for doc in split_documents]

vectors = embeddings.embed_documents(texts)
vectors
# Out:
# [INFO] 2026-04-27 16:35:27,625 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 16:35:27,626 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 16:35:27,637 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 16:35:27,638 [RapidOCR] main.py:50: Using C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 16:35:27,866 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 16:35:27,867 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 16:35:27,869 [RapidOCR] download_file.py:60: File exists and is valid: C:\potenup3\potenup3-agentwt\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...
